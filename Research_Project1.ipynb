# %%
print(df.columns)
# Out:
# Index(['barcode', 'Celltypist:Fetal_Human_Skin:predicted_labels',
#        'pct_counts_gene_group__mito_transcript', 'qc.filter.pass',
#        'Azimuth:predicted.celltype.l3', 'vireo.donor.id',
#        'DoubletFinder.score', 'Azimuth:predicted.celltype.l2.score',
#        'Celltypist:Adult_Human_Skin:over_clustering', 'scDblFinder.score',
#        'Celltypist:Immune_All_High:over_clustering',
#        'Azimuth:mapping.score.celltype.l3', 'cell_passes_hard_filters',
#        'cell_passes_qc-MAD-3,-3,3-per:all_together:score',
#        'pct_counts_in_top_50_genes',
#        'total_counts_gene_group__mito_transcript',
#        'Azimuth:predicted.celltype.l1', 'tranche.id', 'experiment.id',
#        'scds.multiplet', 'Celltypist:Immune_All_Low:over_clustering',
#        'Celltypist:Immune_All_High:conf_score',
#        'Celltypist:Adult_Human_Skin:majority_voting',
#        'Celltypist:Fetal_Human_Skin:majority_voting',
#        'Celltypist:Immune_All_Low:majority_voting', 'scrublet.multiplet',
#        'Celltypist:Adult_Human_Skin:conf_score',
#        'celltypist.celltyp.Immune_All_High', 'phase',
#        'total_counts_gene_group__mito_protein', 'scDblFinder.multiplet',
#        'Azimuth:predicted.celltype.l2',
#        'Celltypist:Fetal_Human_Skin:conf_score', 'qc.filter.pass:score',
#        'Celltypist:Adult_Human_Skin:n_counts', 'G2M_score',
#        'Celltypist:Immune_All_Low:n_counts', 'qc.genes.detected.count',
#        'cell_passes_qc-MAD-3,-3,3-per:all_together',
#        'pct_counts_in_top_500_genes', 'scds.score',
#        'Celltypist:Immune_All_Low:conf_score', 'scrublet.scores',
#        'pct_counts_in_top_100_genes', 'Azimuth:L1_predicted.celltype.l2',
#        'Celltypist:Fetal_Human_Skin:n_counts', 'qc.umi.count.total',
#        'Celltypist:Fetal_Human_Skin:over_clustering',
#        'Celltypist:Immune_All_High:majority_voting',
#        'Azimuth:mapping.score.celltype.l1', 'S_score',
#        'Azimuth:predicted.celltype.l3.score', 'DoubletDecon.multiplet',
#        'Azimuth:predicted.celltype.l1.score', 'DoubletFinder.multiplet',
#        'log10_ngenes_by_count', 'Azimuth:mapping.score.celltype.l2',
#        'cellbender.latent.probability',
#        'Celltypist:Adult_Human_Skin:predicted_labels',
#        'pct_counts_gene_group__mito_protein',
#        'Celltypist:Immune_All_High:n_counts', 'pct_counts_in_top_200_genes',
#        'Azimuth:L0_predicted.celltype.l2',
#        'celltypist.celltyp.Immune_All_Low'],
#       dtype='object')

# %%
import os
import scanpy as sc
import pandas as pd
import matplotlib.pyplot as plt

# Define the donor IDs (adjusted to match the file names)
donor_ids = ['HRX138216', 'HRX138217', 'HRX138218', 'HRX138219', 'HRX138220', 'HRX138221', 'HRX138222', 'HRX138223', 'HRX138224']

# Define the metadata for donor ages, including the age group and specific age
donor_metadata = {
    'HRX138216': {'age_group': 'Young', 'age': 18},
    'HRX138217': {'age_group': 'Young', 'age': 22},
    'HRX138218': {'age_group': 'Young', 'age': 23},
    'HRX138219': {'age_group': 'Middle', 'age': 44},
    'HRX138220': {'age_group': 'Middle', 'age': 47},
    'HRX138221': {'age_group': 'Middle', 'age': 48},
    'HRX138222': {'age_group': 'Older', 'age': 70},
    'HRX138223': {'age_group': 'Older', 'age': 73},
    'HRX138224': {'age_group': 'Older', 'age': 76}
}

# Directory paths for .h5ad and .tsv files
h5ad_directory = '/mnt/bmh01-rds/Eckersley_Lab/NiallGarvey'
tsv_directory = '/mnt/bmh01-rds/Eckersley_Lab/NiallGarvey'

# Process each donor ID one by one
for donor_id in donor_ids:
    print(f"Processing {donor_id}...")

    # Process .h5ad file
    h5ad_file = os.path.join(h5ad_directory, f'{donor_id}.donor.h5ad')
    if os.path.exists(h5ad_file):
        adata = sc.read(h5ad_file)
        adata.obs_names_make_unique()

        # Add donor age group and specific age to the AnnData object
        donor_info = donor_metadata.get(donor_id, {'age_group': 'Unknown', 'age': None})
        adata.obs['donor_age_group'] = donor_info['age_group']
        adata.obs['donor_age'] = donor_info['age']

        # Check if adata.X is populated and has the correct shape
        print(f"adata shape: {adata.shape}")
        if adata.X.shape[0] == 0 or adata.X.shape[1] == 0:
            print(f"Warning: No gene expression data available for {donor_id}. Skipping...")
            continue  # Skip this donor and proceed to the next one

        # Preprocessing steps (normalization, log transformation, etc.)
        sc.pp.normalize_total(adata, target_sum=1e4)
        sc.pp.log1p(adata)

        # Identify highly variable genes (HVGs)
        sc.pp.highly_variable_genes(adata, min_mean=0.1, max_mean=10, min_disp=0.5)
        adata = adata[:, adata.var['highly_variable']]

        # Plot the highly variable genes
        sc.pl.highly_variable_genes(adata, show=True)

        # Perform analysis specific to this donor here (e.g., differential expression, UMAP, etc.)
        # Example of UMAP:
        sc.pp.neighbors(adata, n_neighbors=10, n_pcs=40)
        sc.tl.umap(adata)
        sc.pl.umap(adata, color=['donor_age_group', 'donor_age'], title=f'UMAP for {donor_id}')

        # Clear the data from memory
        del adata
    else:
        print(f"File {h5ad_file} does not exist. Skipping...")

    # Process .tsv file (if needed)
    tsv_file = os.path.join(tsv_directory, f'{donor_id}.donor.tsv')
    if os.path.exists(tsv_file):
        df = pd.read_csv(tsv_file, sep='\t')

        # Add donor age and age group to the DataFrame
        donor_info = donor_metadata.get(donor_id, {'age_group': 'Unknown', 'age': None})
        df['donor_age_group'] = donor_info['age_group']
        df['donor_age'] = donor_info['age']

        # Display the first few rows of the DataFrame with the new 'donor_age' and 'donor_age_group' columns
        print(df.head())

        # Clear the DataFrame from memory
        del df
    else:
        print(f"TSV file {tsv_file} does not exist. Skipping...")

    print(f"Finished processing {donor_id}.\n")
# Out:
# Processing HRX138216...
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[1], line 33
#      31 h5ad_file = os.path.join(h5ad_directory, f'{donor_id}.donor.h5ad')
#      32 if os.path.exists(h5ad_file):
# ---> 33     adata = sc.read(h5ad_file)
#      34     adata.obs_names_make_unique()
#      36     # Add donor age group and specific age to the AnnData object
#
# File ~/.conda/envs/research_project1_env/lib/python3.13/site-packages/legacy_api_wrap/__init__.py:82, in legacy_api.<locals>.wrapper.<locals>.fn_compatible(*args_all, **kw)
#      79 @wraps(fn)
#      80 def fn_compatible(*args_all: P.args, **kw: P.kwargs) -> R:
#      81     if len(args_all) <= n_positional:
# ---> 82         return fn(*args_all, **kw)
#      84     args_pos: P.args
#      85     args_pos, args_rest = args_all[:n_positional], args_all[n_positional:]
#
# File ~/.conda/envs/research_project1_env/lib/python3.13/site-packages/scanpy/readwrite.py:142, in read(filename, backed, sheet, ext, delimiter, first_column_names, backup_url, cache, cache_compression, **kwargs)
#     140 filename = Path(filename)  # allow passing strings
#     141 if is_valid_filename(filename):
# --> 142     return _read(
#     143         filename,
#     144         backed=backed,
#     145         sheet=sheet,
#     146         ext=ext,
#     147         delimiter=delimiter,
#     148         first_column_names=first_column_names,
#     149         backup_url=backup_url,
#     150         cache=cache,
#     151         cache_compression=cache_compression,
#     152         **kwargs,
#     153     )
#     154 # generate filename and read to dict
#     155 filekey = str(filename)
#
# File ~/.conda/envs/research_project1_env/lib/python3.13/site-packages/scanpy/readwrite.py:777, in _read(filename, backed, sheet, ext, delimiter, first_column_names, backup_url, cache, cache_compression, suppress_cache_warning, **kwargs)
#     775 if ext in {"h5", "h5ad"}:
#     776     if sheet is None:
# --> 777         return read_h5ad(filename, backed=backed)
#     778     else:
#     779         logg.debug(f"reading sheet {sheet} from file {filename}")
#
# File ~/.conda/envs/research_project1_env/lib/python3.13/site-packages/anndata/_io/h5ad.py:260, in read_h5ad(filename, backed, as_sparse, as_sparse_fmt, chunk_size)
#     257         return read_dataframe(elem)
#     258     return func(elem)
# --> 260 adata = read_dispatched(f, callback=callback)
#     262 # Backwards compat (should figure out which version)
#     263 if "raw.X" in f:
#
# File ~/.conda/envs/research_project1_env/lib/python3.13/site-packages/anndata/experimental/_dispatch_io.py:42, in read_dispatched(elem, callback)
#      38 from anndata._io.specs import _REGISTRY, Reader
#      40 reader = Reader(_REGISTRY, callback=callback)
# ---> 42 return reader.read_elem(elem)
#
# File ~/.conda/envs/research_project1_env/lib/python3.13/site-packages/anndata/_io/utils.py:213, in report_read_key_on_error.<locals>.func_wrapper(*args, **kwargs)
#     211     raise ValueError("No element found in args.")
#     212 try:
# --> 213     return func(*args, **kwargs)
#     214 except Exception as e:
#     215     path, key = _get_display_path(store).rsplit("/", 1)
#
# File ~/.conda/envs/research_project1_env/lib/python3.13/site-packages/anndata/_io/specs/registry.py:281, in Reader.read_elem(self, elem, modifiers)
#     279 if self.callback is None:
#     280     return read_func(elem)
# --> 281 return self.callback(read_func, elem.name, elem, iospec=iospec)
#
# File ~/.conda/envs/research_project1_env/lib/python3.13/site-packages/anndata/_io/h5ad.py:244, in read_h5ad.<locals>.callback(func, elem_name, elem, iospec)
#     238 def callback(func, elem_name: str, elem, iospec):
#     239     if iospec.encoding_type == "anndata" or elem_name.endswith("/"):
#     240         return AnnData(
#     241             **{
#     242                 # This is covering up backwards compat in the anndata initializer
#     243                 # In most cases we should be able to call `func(elen[k])` instead
# --> 244                 k: read_dispatched(elem[k], callback)
#     245                 for k in elem.keys()
#     246                 if not k.startswith("raw.")
#     247             }
#     248         )
#     249     elif elem_name.startswith("/raw."):
#     250         return None
#
# File ~/.conda/envs/research_project1_env/lib/python3.13/site-packages/anndata/experimental/_dispatch_io.py:42, in read_dispatched(elem, callback)
#      38 from anndata._io.specs import _REGISTRY, Reader
#      40 reader = Reader(_REGISTRY, callback=callback)
# ---> 42 return reader.read_elem(elem)
#
# File ~/.conda/envs/research_project1_env/lib/python3.13/site-packages/anndata/_io/utils.py:213, in report_read_key_on_error.<locals>.func_wrapper(*args, **kwargs)
#     211     raise ValueError("No element found in args.")
#     212 try:
# --> 213     return func(*args, **kwargs)
#     214 except Exception as e:
#     215     path, key = _get_display_path(store).rsplit("/", 1)
#
# File ~/.conda/envs/research_project1_env/lib/python3.13/site-packages/anndata/_io/specs/registry.py:281, in Reader.read_elem(self, elem, modifiers)
#     279 if self.callback is None:
#     280     return read_func(elem)
# --> 281 return self.callback(read_func, elem.name, elem, iospec=iospec)
#
# File ~/.conda/envs/research_project1_env/lib/python3.13/site-packages/anndata/_io/h5ad.py:258, in read_h5ad.<locals>.callback(func, elem_name, elem, iospec)
#     255 elif elem_name in {"/obs", "/var"}:
#     256     # Backwards compat
#     257     return read_dataframe(elem)
# --> 258 return func(elem)
#
# File ~/.conda/envs/research_project1_env/lib/python3.13/site-packages/anndata/_io/specs/methods.py:143, in read_basic(elem, _reader)
#     141     if "h5sparse_format" in elem.attrs:
#     142         return sparse_dataset(elem).to_memory()
# --> 143     return {k: _reader.read_elem(v) for k, v in elem.items()}
#     144 elif isinstance(elem, h5py.Dataset):
#     145     return h5ad.read_dataset(elem)
#
# File ~/.conda/envs/research_project1_env/lib/python3.13/site-packages/anndata/_io/utils.py:213, in report_read_key_on_error.<locals>.func_wrapper(*args, **kwargs)
#     211     raise ValueError("No element found in args.")
#     212 try:
# --> 213     return func(*args, **kwargs)
#     214 except Exception as e:
#     215     path, key = _get_display_path(store).rsplit("/", 1)
#
# File ~/.conda/envs/research_project1_env/lib/python3.13/site-packages/anndata/_io/specs/registry.py:281, in Reader.read_elem(self, elem, modifiers)
#     279 if self.callback is None:
#     280     return read_func(elem)
# --> 281 return self.callback(read_func, elem.name, elem, iospec=iospec)
#
# File ~/.conda/envs/research_project1_env/lib/python3.13/site-packages/anndata/_io/h5ad.py:258, in read_h5ad.<locals>.callback(func, elem_name, elem, iospec)
#     255 elif elem_name in {"/obs", "/var"}:
#     256     # Backwards compat
#     257     return read_dataframe(elem)
# --> 258 return func(elem)
#
# File ~/.conda/envs/research_project1_env/lib/python3.13/site-packages/anndata/_io/specs/methods.py:764, in read_sparse(elem, _reader)
#     757 @_REGISTRY.register_read(H5Group, IOSpec("csc_matrix", "0.1.0"))
#     758 @_REGISTRY.register_read(H5Group, IOSpec("csr_matrix", "0.1.0"))
#     759 @_REGISTRY.register_read(ZarrGroup, IOSpec("csc_matrix", "0.1.0"))
#    (...)    762     elem: GroupStorageType, *, _reader: Reader
#     763 ) -> sparse.spmatrix | SpArray:
# --> 764     return sparse_dataset(elem).to_memory()
#
# File ~/.conda/envs/research_project1_env/lib/python3.13/site-packages/anndata/_core/sparse_dataset.py:624, in BaseCompressedSparseDataset.to_memory(self)
#     620 format_class = get_memory_class(
#     621     self.format, use_sparray_in_io=settings.use_sparse_array_on_read
#     622 )
#     623 mtx = format_class(self.shape, dtype=self.dtype)
# --> 624 mtx.data = self._data[...]
#     625 mtx.indices = self._indices[...]
#     626 mtx.indptr = self._indptr
#
# File h5py/_objects.pyx:54, in h5py._objects.with_phil.wrapper()
#
# File h5py/_objects.pyx:55, in h5py._objects.with_phil.wrapper()
#
# File ~/.conda/envs/research_project1_env/lib/python3.13/site-packages/h5py/_hl/dataset.py:802, in Dataset.__getitem__(self, args, new_dtype)
#     800 if self._fast_read_ok and (new_dtype is None):
#     801     try:
# --> 802         return self._fast_reader.read(args)
#     803     except TypeError:
#     804         pass  # Fall back to Python read pathway below
#
# File h5py/_selector.pyx:368, in h5py._selector.Reader.read()
#
# File h5py/_selector.pyx:342, in h5py._selector.Reader.make_array()
#
# MemoryError: Unable to allocate 111. MiB for an array with shape (29204368,) and data type float32
# Error raised while reading key 'log1p_cp10k' of <class 'h5py._hl.group.Group'> from /layers
